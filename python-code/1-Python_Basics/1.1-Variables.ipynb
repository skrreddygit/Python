# %% [markdown]
# ### Variables
#
# Variables are fundamental elements in programming used to store data that can be referenced and manipulated in a program. In Python, variables are created when you assign a value to them, and they do not need explicit declaration to reserve memory space. The declaration happens automatically when you assign a value to a variable.
#
#
# * Introduction to Variables
# * Declaring and Assigning Variables
# * Naming Conventions
# * Understanding Variable Types
# * Type Checking and Conversion
# * Dynamic typing
# * Practical Examples and Common Errors

# %%
a=10
print(a)
print(type(a))
# Out:
# 10
# <class 'int'>

# %%
## declaring and assigning variables

age=25
height=5.8
name="alien"
is_student=False

## printing the variables
print("age:", age)
print("height:", height)
print("name:", name)
print("is_student:", is_student)
# Out:
# age: 25
# height: 5.8
# name: alien
# is_student: False

# %%
## Naming Convention - Imp
## Variable Names Should be Descriptive
## They must start with a letter or '_' and contain lettrs,numbers and underscores
## Variable names are case-sensitive


## Valid variable Names
first_name="alien"
last_name="unknown"

# %%
## Invalid Variable Names

# 2age = 30
# first-name="alien"
# @name="alien"

# %%
# case-sensitivity

name="alien"
Name="unknown"

name==Name
# Out:
# False

# %%
## understanding variable types
## Python is dynamically typed, type of a variable is determined at runtime

age=25        #int
height=5.6    #float
name="alien"  #string
is_student=True #bool

# %%
## Type Checking and Conversion
type(height)

age_str=str(age)
print(age_str)
print(type(age_str))
# Out:
# 25
# <class 'str'>

# %%
name ="alien"
name_int = int(name)
print(name_int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 name ="alien"
# ----> 2 name_int = int(name)
#       3 print(name_int)
#
# ValueError: invalid literal for int() with base 10: 'alien'

# %%
print(int(height))
float(int(height))
# Out:
# 5
# 5.0

# %%
## Dynamic Typing 
## Python allows type of variable to change as the program executes

var=10
print(var,type(var))

var="hello"
print(var,type(var))

var=3.14
print(var,type(var))
# Out:
# 10 <class 'int'>
# hello <class 'str'>
# 3.14 <class 'float'>

# %%
## Input from the user

age = input("What is the age")
print(age,type(age))
# Out:
#  <class 'str'>

# %%
age = int(input("What is the age"))
print(age,type(age))
# Out:
# 20 <class 'int'>

# %%
## Calculator Program

num1 = int(input("Enter First Number"))
num2 = int(input("Enter Second Number"))

add = num1+num2
difference = num1-num2
multiply = num1*num2
division = num1/num2

print(f"Addition of given two Numbers {add}")
print(f"difference of given two Numbers {difference}")
print(f"Product of given two Numbers {multiply}")
print(f"Division of given two Numbers {division}")
# Out:
# Addition of given two Numbers 30
# difference of given two Numbers -10
# Product of given two Numbers 200
# Division of given two Numbers 0.5

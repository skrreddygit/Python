# %%
import os

cwd = os.getcwd()
print(f"Current working directory {cwd}")
# Out:
# Current working directory c:\Users\yaswa\Downloads\python-code\6-FileHandling.ipynb

# %%
## create a directory

new_directory = "package"
os.mkdir(new_directory)
print(f"{new_directory} is created")
# Out:
# package is created

# %%
## Listing Files and directories

items = os.listdir('.')
print(items)
# Out:
# ['6-1.FileOperations.ipynb', '6-2.FilePath.ipynb', 'destination.txt', 'example.bin', 'example.txt', 'package']

# %%
#### joining Paths - Very Important

dir_name = "folder"
file_name = "file.txt"

full_path = os.path.join(dir_name,file_name)
print(full_path)
# Out:
# folder\file.txt

# %%
path = "example.txt"

if os.path.exists(path):
    print(f"The path {path} exists")
else:
    print("path {path} doesnt exists")
# Out:
# The path example.txt exists

# %%
### checking if a Path is a File or Directory


import os

path = "package"

if os.path.isfile(path):
    print(f"The path {path} is a file")

elif os.path.isdir(path):
    print(f"path {path} is a Directory")

else:
    print(f"path {path} is neither a file or directory")
# Out:
# path package is a Directory

# %%
## getting the absolute path

relative_path = "example.txt"
absolute_path=os.path.abspath(relative_path)
print(absolute_path)
# Out:
# c:\Users\yaswa\Downloads\python-code\6-FileHandling.ipynb\example.txt
